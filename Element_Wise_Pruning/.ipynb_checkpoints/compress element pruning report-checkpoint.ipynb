# %%
import os
import sys
import re
from collections import OrderedDict

# %%
#2018-10-28 00:24:19,407 - Total sparsity: 19.39
#2018-10-28 00:24:20,573 - ==> Top1: 44.410    Top5: 92.320    Loss: 1.512

fname = './element_sparsity_74.94-Top1_90.02.log'
with open(fname) as fp:  
    for cnt, line in enumerate(fp):
        #print("Line {}: {}".format(cnt, line))
        pattern1 = re.compile(r"(\S+) (\S+) - Total sparsity: (\d+.\d+)")
        match1 = pattern1.match(line)
        if match1:
            ser_date, ser_no, sparsity_str = match1.groups()
            #print('{:s}'.format(sparsity_str))
        
        pattern2 = re.compile(r"(\S+) (\S+) - ==> Top1: (\d+.\d+)    Top5: (\d+.\d+)    Loss: (\d+.\d+)")
        match2 = pattern2.match(line)
        if match2:
            ser_date, ser_no, top1_str, top5_str, loss_str = match2.groups()
            #print('{:s}, {:s}, {:s}, {:s}'.format(sparsity_str, top1_str, top5_str, loss_str))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-5269b043e924> in <module>
#       3
#       4 fname = './element_sparsity_74.94-Top1_90.02.log'
# ----> 5 with open(fname) as fp:
#       6     for cnt, line in enumerate(fp):
#       7         #print("Line {}: {}".format(cnt, line))
#
# FileNotFoundError: [Errno 2] No such file or directory: './element_sparsity_74.94-Top1_90.02.log'

# %%
dictionary_sparsity = OrderedDict()
dictionary_top1 = OrderedDict()
dictionary_top5 = OrderedDict()
dictionary_loss = OrderedDict()

#2018-10-28 00:24:19,407 - Total sparsity: 19.39
#2018-10-28 00:24:20,573 - ==> Top1: 44.410    Top5: 92.320    Loss: 1.512

fname = '../report/compress_sparsity_74.94-Top1_90.02.log'
with open(fname) as fp:  
    i = 0
    for cnt, line in enumerate(fp):
        #print("Line {}: {}".format(cnt, line))
        pattern1 = re.compile(r"(\S+) (\S+) - Total sparsity: (\d+.\d+)")
        match1 = pattern1.match(line)
        if match1:
            ser_date, ser_no, sparsity_str = match1.groups()
            #print('{:s}'.format(sparsity_str))
        
        pattern2 = re.compile(r"(\S+) (\S+) - ==> Top1: (\d+.\d+)    Top5: (\d+.\d+)    Loss: (\d+.\d+)")
        match2 = pattern2.match(line)
        if match2:
            ser_date, ser_no, top1_str, top5_str, loss_str = match2.groups()
            #print('{:s}, {:s}, {:s}, {:s}'.format(sparsity_str, top1_str, top5_str, loss_str))

            sparsity = float(sparsity_str)
            top1 = float(top1_str)
            top5 = float(top5_str)
            loss = float(loss_str)
                        
            i += 1
            dictionary_sparsity[i] = sparsity
            dictionary_top1[i] = top1
            dictionary_top5[i] = top5
            dictionary_loss[i] = loss
            
print(dictionary_sparsity)
print(dictionary_top1)
#print(dictionary_top5)
#print(dictionary_loss)
# Out:
# OrderedDict([(1, 19.39), (2, 19.39), (3, 30.82), (4, 30.82), (5, 38.34), (6, 38.34), (7, 44.08), (8, 44.08), (9, 48.88), (10, 48.88), (11, 52.92), (12, 52.92), (13, 56.23), (14, 56.23), (15, 59.07), (16, 59.07), (17, 61.45), (18, 61.45), (19, 63.53), (20, 63.53), (21, 65.38), (22, 65.38), (23, 67.01), (24, 67.01), (25, 68.47), (26, 68.47), (27, 69.78), (28, 69.78), (29, 71.0), (30, 71.0), (31, 72.12), (32, 72.12), (33, 73.14), (34, 73.14),
.52), (143, 88.25), (144, 88.41), (145, 88.04), (146, 88.04), (147, 88.24), (148, 87.19), (149, 88.56), (150, 86.97), (151, 88.3), (152, 87.4), (153, 88.53), (154, 88.73), (155, 88.35), (156, 88.82), (157, 88.16), (158, 87.87), (159, 88.32), (160, 88.38), (161, 87.56), (162, 88.18), (163, 87.72), (164, 88.55), (165, 88.3), (166, 88.38), (167, 87.92), (168, 88.24), (169, 87.61), (170, 88.18), (171, 87.82), (172, 87.86), (173, 88.07), (174, 88.26), (175, 88.31), (176, 88.16), (177, 86.7), (178, 88.53), (179, 87.81), (180, 87.73), (181, 88.06), (182, 87.4), (183, 88.31), (184, 87.81), (185, 87.15), (186, 87.75), (187, 87.39), (188, 87.24), (189, 88.22), (190, 87.55), (191, 87.51), (192, 88.02), (193, 88.59), (194, 88.03), (195, 88.27), (196, 87.1), (197, 87.24), (198, 87.05), (199, 87.57), (200, 88.02), (201, 90.12), (202, 90.16), (203, 89.95), (204, 90.3), (205, 90.23), (206, 90.15), (207, 90.2), (208, 90.1), (209, 90.18), (210, 90.08), (211, 90.1), (212, 90.08), (213, 90.14), (214, 90.44), (215, 90.13), (216, 90.29), (217, 90.26), (218, 90.28), (219, 90.01), (220, 90.19), (221, 90.1), (222, 90.19), (223, 90.02), (224, 90.05), (225, 90.18), (226, 90.23), (227, 90.14), (228, 90.1), (229, 90.12), (230, 90.18), (231, 89.98), (232, 90.08), (233, 89.9), (234, 90.1), (235, 90.05), (236, 89.96), (237, 90.02), (238, 90.36), (239, 90.09), (240, 90.21), (241, 90.18), (242, 90.12), (243, 89.85), (244, 89.96), (245, 89.95), (246, 89.94), (247, 89.86), (248, 89.85), (249, 90.0), (250, 89.99), (251, 89.9), (252, 89.72), (253, 90.08), (254, 90.02), (255, 90.0), (256, 89.91), (257, 89.99), (258, 90.06), (259, 90.0), (260, 90.0), (261, 90.26), (262, 90.15), (263, 90.15), (264, 90.03), (265, 90.1), (266, 90.05), (267, 90.25), (268, 90.11), (269, 90.1), (270, 90.03), (271, 90.04), (272, 89.98), (273, 90.03), (274, 90.19), (275, 90.09), (276, 90.05), (277, 90.04), (278, 90.05), (279, 89.96), (280, 90.06), (281, 90.02), (282, 90.04), (283, 89.94), (284, 89.9), (285, 90.03), (286, 89.95), (287, 90.1), (288, 89.84), (289, 90.09), (290, 90.16), (291, 89.93), (292, 90.11), (293, 89.96), (294, 90.01), (295, 89.99), (296 ...

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()

fig.set_figheight(20)
fig.set_figwidth(20)

ax1.set_title('Element-Wise Pruning on Resnet20_Cifar', fontsize=20)

ax2 = ax1.twinx()
ax2.figure.figsize=(120,120)

ax1.plot(list(dictionary_top1.keys()), list(dictionary_top1.values()),'b-')
ax2.plot(list(dictionary_sparsity.keys()), list(dictionary_sparsity.values()), 'r-')

ax1.tick_params(axis='both', which='major', labelsize=20)
ax2.tick_params(axis='y', which='major', labelsize=20)

ax1.set_xlabel('Epoch', fontsize=20)
ax1.set_ylabel('Accuracy', fontsize=20, color='g')
ax2.set_ylabel('Sparsity', fontsize=20, color='b')

ax1.set(ylim=[0, 100])
ax2.set(ylim=[0, 100])

ax1.grid()
plt.show()
